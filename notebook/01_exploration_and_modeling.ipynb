# %% [markdown]
# <a href="https://colab.research.google.com/github/Igor1325476/product-category-classification/blob/main/notebook/01_exploration_and_modeling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
